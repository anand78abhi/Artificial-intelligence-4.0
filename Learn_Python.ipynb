# %% [markdown]
# <a href="https://colab.research.google.com/github/anand78abhi/Artificial-intelligence-4.0/blob/main/Learn_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#question 1 part A
import pandas as pd
df= pd.read_csv('concrete.csv')
print(df)
df.drop(df.columns[2],axis=1,inplace=True)
df.drop(6,axis=0,inplace=True)
df.head()
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0      141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1      168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2      250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3      266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4      154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   135.0    0.0  166.0  180.0          10.0      961.0    805.0   28
# 1026   531.3    0.0    0.0  141.8          28.2      852.1    893.7    3
# 1027   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1028   342.0   38.0    0.0  228.0           0.0      932.0    670.0  270
# 1029   540.0    0.0    0.0  173.0           0.0     1125.0    613.0    7
#
#       strength
# 0        29.89
# 1        23.51
# 2        29.22
# 3        45.85
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-30-1af3962d8ca7> in <cell line: 2>()
#       1 from google.colab import sheets
# ----> 2 sheet = sheets.InteractiveSheet(df=df)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/sheets.py in __init__(self, title, url, sheet_id, df, worksheet_id, worksheet_name, credentials, include_column_headers, display)
#     110       url = f'https://docs.google.com/spreadsheets/d/{sheet_id}'
#     111     self._credentials = credentials
# --> 112     self._ensure_gspread_client()
#     113
#     114     self.sheet = self._load_or_create_sheet(url, title)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/sheets.py in _ensure_gspread_client(self)
#     166     global _gspread_client
#     167     if _gspread_client is None:
# --> 168       creds = InteractiveSheet.generate_creds(self._credentials)
# ...

# %%
import pandas as pd
dataset={
   'HOUSE':["Avalon","Cross winds","The white house","The rectory","Larch wood","orchard house"],
   'SALE PRICE(100$)':[2050,2080,2150,2150,1999,1900],
   'SIZE(sqft)':[2650,2600,2554,2921,2580,2580],
   'AGE(years)':[13,"*",6,3,4,4]
}
df=pd.DataFrame(dataset)
print(df)
locate=df.drop(df.columns[1],axis=1)
print(locate)
# Out:
#              HOUSE  SALE PRICE(100$)  SIZE(sqft) AGE(years)
# 0           Avalon              2050        2650         13
# 1      Cross winds              2080        2600          *
# 2  The white house              2150        2554          6
# 3      The rectory              2150        2921          3
# 4       Larch wood              1999        2580          4
# 5    orchard house              1900        2580          4
#              HOUSE  SIZE(sqft) AGE(years)
# 0           Avalon        2650         13
# 1      Cross winds        2600          *
# 2  The white house        2554          6
# 3      The rectory        2921          3
# 4       Larch wood        2580          4
# 5    orchard house        2580          4
#              HOUSE  SALE PRICE(100$)  SIZE(sqft) AGE(years)
# 0           Avalon              2050        2650         13
# 1      Cross winds              2080        2600          *
# 2  The white house              2150        2554          6
# ...
